# %%
import cv2
import numpy as np

# %%
print(cv2.IMREAD_COLOR)
# Out:
# 1

# %%
im = cv2.imread('./images/lena.png',cv2.IMREAD_COLOR)

# %%
print(type(im), im.shape)
# Out:
# <class 'numpy.ndarray'> (512, 512, 3)

# %%
# cv2.imshow('lena', im)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
im = cv2.imread('./images/mandril_color.png',cv2.IMREAD_COLOR)
b,g,r = cv2.split(im)
print(type(b), b.shape)
# Out:
# <class 'numpy.ndarray'> (512, 512)

# %%
# cv2.imshow('xxx', g)
# cv2.waitKey(1)
# cv2.destroyAllWindows()

# %%
b = im[:,:,0]
g = im[:,:,1]
r = im[:,:,2]
type(b[0,0])
# print(type(b), b.shape)
# print(type(g), g.shape)
# print(type(r), r.shape)
# Out:
# numpy.uint8

# %%
b = b.astype(np.float16)
g = g.astype(np.float16)
r = r.astype(np.float16)
print(type(b[0,0]),b[0,0])
gray = 0.299*r + 0.587*g + 0.114*b
print('type gray ' , type(gray[0,0]))
gray = gray.astype(np.uint8)
print('type gray after astype ' , type(gray[0,0]))
# Out:
# <class 'numpy.float16'> 62.0
# type gray  <class 'numpy.float16'>
# numpy.uint8
