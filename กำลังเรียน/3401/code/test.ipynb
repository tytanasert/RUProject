# %%
import cv2

# %%
import cv2

print(cv2.IMREAD_COLOR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(cv2.IMREAD_COLOR)
#
# NameError: name 'cv2' is not defined

# %%
im = cv2.imread('./images/lena.png',cv2.IMREAD_COLOR)
